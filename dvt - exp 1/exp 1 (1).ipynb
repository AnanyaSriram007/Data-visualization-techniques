# %%
print("Welcome to data analytics lab")
# Out:
# Welcome to data analytics lab

# %%
a=20
b=10
print("Addition =",a+b) 
print("Subtraction =",a-b) 
print("Multiplication =",a*b) 
print("Division =",a/b)
# Out:
# Addition = 30
# Subtraction = 10
# Multiplication = 200
# Division = 2.0

# %%
name = "John" 
dept = "AI&DS" 
cgpa = 8.9

print("Name:",name) 
print("Department:",dept) 
print("CGPA:",cgpa)
# Out:
# Name: John
# Department: AI&DS
# CGPA: 8.9

# %%
import numpy as np
a = np.array([10,20,30,40,50])
print(a)
print("Mean =",np.mean(a))
print("Sum =",np.sum(a))
# Out:
# [10 20 30 40 50]
# Mean = 30.0
# Sum = 150

# %%
import pandas as pd
data = {
'Name':['John','David','Alex'], 'Marks':[85,90,95]
}

df = pd.DataFrame(data) 
print(df)
# Out:
#     Name  Marks
# 0   John     85
# 1  David     90
# 2   Alex     95

# %%
import matplotlib.pyplot as plt 
x=[1,2,3,4,5]
y=[10,20,15,25,30]

plt.plot(x,y)
plt.title("Sample Line Graph") 
plt.xlabel("X Axis") 
plt.ylabel("Y Axis") 
plt.show()
