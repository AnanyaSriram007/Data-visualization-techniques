# %%
import pandas as pd
df=pd.read_csv(r"D:\Ananya\Students.csv")
print(df)
# Out:
#    Roll No   Name  Marks
# 0      101  Arun      85
# 1      102   Bala     90
# 2      103  Divya     91
# 3      104  Priya     80
# 4      105   Ravi     95
# 5      106  lekha    100
# 6      107  anaya    100

# %%
print(df.head())
# Out:
#    Roll No   Name  Marks
# 0      101  Arun      85
# 1      102   Bala     90
# 2      103  Divya     91
# 3      104  Priya     80
# 4      105   Ravi     95

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Roll No  7 non-null      int64
#  1   Name     7 non-null      object
#  2   Marks    7 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 300.0+ bytes
# None

# %%
print(df.describe())
# Out:
#           Roll No       Marks
# count    7.000000    7.000000
# mean   104.000000   91.571429
# std      2.160247    7.457818
# min    101.000000   80.000000
# 25%    102.500000   87.500000
# 50%    104.000000   91.000000
# 75%    105.500000   97.500000
# max    107.000000  100.000000

# %%
df=pd.read_excel(r"D:\Ananya\student.xlsx")
print(df)
# Out:
#    Roll No   Name  Marks
# 0      101  Arun      85
# 1      102   Bala     90
# 2      103  Divya     91
# 3      104  Priya     80
# 4      105   Ravi     95
# 5      106  lekha    100
# 6      107  anaya    100

# %%
url="https://gist.githubusercontent.com/pyPRO2019/dc44ae45f7cfe2f2a34fec30db4678eb/raw/df247df4e11260c669f986d0de589a90459d7e7b/students_data.csv"
df=pd.read_csv(url)
print(df.head())
# Out:
#    YearofStudy                    Course  Age  ApproxHeight  ApproxWeight  \
# 0  Second Year               MATHEMATICS   20           152            80
# 1   First Year  ECONOMICS AND STATISTICS   29           182            79
# 2  Fourth Year               MATHEMATICS   22           167            64
# 3  Second Year  ECONOMICS AND STATISTICS   23           149            52
# 4  Second Year               MATHEMATICS   18           150            70
#
#    KCSE  Yr_JoinCampus      SitKCSE  Expense_Semester  Expense_Accommodation  \
# 0  2016           2018     Central               8744                   6043
# 1  2010           2010  Rift Valley             26293                  14782
# 2  2015           2016      Western             44105                  19224
# 3  2016           2018        Coast             33954                  18795
# 4  2013           2018      Western             18113                  25569
#
#   Previous_Exam_MeanGrade
# 0                       B
# ...

# %%
df.to_csv('output.csv',index=False)
print("CSV File Exported")
# Out:
# CSV File Exported

# %%
df.to_excel('output.xlsx',index=False)
print("Excel File Exported")
# Out:
# Excel File Exported

# %%
df.to_json('output.json')
print("JSON File exported")
# Out:
# JSON File exported
